# %% [markdown]
# # Lightning 05 — SFT with Curriculum Learning
#
# **Week 5 task** — Run on Lightning L40S.
#
# Loads CPT checkpoint. Trains on 40-60k ChatML examples.
# Target post-SFT: COBOLEval ≥65% compile, ≥40 Pass@1.

# %%
import sys, os
sys.path.insert(0, '/teamspace/studios/this_studio/Qwen-COBOL')
os.chdir('/teamspace/studios/this_studio/Qwen-COBOL')

# %%
CONFIG = 'config/training_qwen36_27b.yaml'
from src.train.sft import run_sft
run_sft(CONFIG)
